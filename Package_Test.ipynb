# %%
import pandas as pd
from MyFirstPackage import ttest
import numpy as np

from sklearn.datasets import fetch_california_housing

# %%
'''
df = pd.read_csv('./시청자미디어재단_체험형미디어교육_20230704.csv', encoding='cp949')

df['강좌정원수'] = df['강좌정원수'].apply(lambda x : x.replace('미정', '10'))
df['강좌정원수'] = df['강좌정원수'].astype(int)
'''

# %%
dataset = fetch_california_housing()
dataset
# Out:
# {'data': array([[   8.3252    ,   41.        ,    6.98412698, ...,    2.55555556,
#            37.88      , -122.23      ],
#         [   8.3014    ,   21.        ,    6.23813708, ...,    2.10984183,
#            37.86      , -122.22      ],
#         [   7.2574    ,   52.        ,    8.28813559, ...,    2.80225989,
#            37.85      , -122.24      ],
#         ...,
#         [   1.7       ,   17.        ,    5.20554273, ...,    2.3256351 ,
#            39.43      , -121.22      ],
#         [   1.8672    ,   18.        ,    5.32951289, ...,    2.12320917,
#            39.43      , -121.32      ],
#         [   2.3886    ,   16.        ,    5.25471698, ...,    2.61698113,
#            39.37      , -121.24      ]]),
#  'target': array([4.526, 3.585, 3.521, ..., 0.923, 0.847, 0.894]),
#  'frame': None,
#  'target_names': ['MedHouseVal'],
#  'feature_names': ['MedInc',
#   'HouseAge',
#   'AveRooms',
#   'AveBedrms',
#   'Population',
#   'AveOccup',
#   'Latitude',
# ...

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude   Mean
# ...

# %%
df = pd.DataFrame(dataset.data, columns = dataset.feature_names)
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude
# 0        -122.23
# ...

# %%
df['Mean'] = '-'

# %%
df['Mean'] = ['Old' if i < df.HouseAge.mean() else 'New' for i in df.HouseAge]

# %%
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810    2.507856  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880    3.380392  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446    2.695482  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059    2.746634  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081    2.752048  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333    2.926857  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789    2.551450  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092    3.003029  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920    2.869818  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264    3.142076  2.616981     39.37
#
#        Longitude  Mean
# ...

# %%
df['AveRooms'] = np.log10(df['AveRooms'])

# %%
df['Population'] = np.log10(df['Population'])

# %%
ttest.ttest_auto(df, 'Mean', 'AveRooms', 'Old', 'New')
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# New v.s. Old: t-test independent samples with Bonferroni correction, P_val=1.313e-167 stat=-2.785e+01
